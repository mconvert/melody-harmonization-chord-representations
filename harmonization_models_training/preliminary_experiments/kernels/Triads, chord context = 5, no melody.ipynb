# %%
import re
import time

import numpy as np
import matplotlib.pyplot as plt

from sklearn.metrics import confusion_matrix
from sklearn.model_selection import StratifiedShuffleSplit
from keras.models import Model
from keras.models import load_model
from keras.layers import Input, Dense, GRU, concatenate
from keras import metrics
from keras import backend as K
from keras.utils import plot_model
from keras.callbacks import EarlyStopping, ModelCheckpoint

from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot

# Custom library for the project
import sys
sys.path.insert(0, '../../../src')
import harmoutil

# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
# # Remove when done with kernel
import importlib
importlib.reload(harmoutil)
# Out:
# <module 'harmoutil' from '../../../src/harmoutil.py'>

# %%
### Load raw data ###
raw_data = harmoutil.load_pickled_data("../../../data/refined_data.pkl") # lists of (chord label, melody seqs) by sections

### Augment data ###
augmented_data = harmoutil.transpose_and_augment_data(raw_data)

data = [harmoutil.to_triads(section) for section in augmented_data]
data = [harmoutil.melody_to_octave_range(section) for section in data]

chords = [ch for section in data for ch, mel in section]
melodies_by_beats = [mel for section in data for ch, mel in section]

melodies_by_notes = []
for mel in melodies_by_beats:
    melodies_by_notes.append([n for b in mel for n in b])
notes = [n for sec in melodies_by_notes for n in sec]
print(len(chords), len(melodies_by_beats), len(melodies_by_notes), len(notes))
# Out:
# 334344 334344 334344 2209944

# %%
### Visualize classes statistics ###

chord_seq_lengths = [len(section) for section in data]

plt.clf()

labels = sorted(list(set(chord_seq_lengths)))
x_axis = range(len(labels))
y_axis = [chord_seq_lengths.count(lab) for lab in labels]

plt.figure(figsize=(15,5))
plt.bar(x_axis, y_axis, tick_label=labels)
plt.xticks(rotation='vertical')
plt.title('Chord statistics')
plt.show()


melody_seq_lengths = [len(sec) for sec in melodies_by_notes]
    
labels = sorted(list(set(melody_seq_lengths)))
x_axis = range(len(labels))
y_axis = [melody_seq_lengths.count(lab) for lab in labels]

plt.figure(figsize=(15,5))
plt.bar(x_axis, y_axis, tick_label=labels)
plt.xticks(rotation='vertical')
plt.title('Chord statistics')
plt.show()

# %%
### Define class integer mappings ###
notes_index = dict(
    [(c, i) for i, c in enumerate(sorted(list(set(notes)))[1:])])
notes_index[-1] = len(notes_index)
notes_index['<end>'] = len(notes_index)
notes_index['<pad>'] = len(notes_index)

index_notes = dict(
    [(v, k) for k, v in notes_index.items()])


chords_index = dict(
    [(c, i) for i, c in enumerate(sorted(list(set(chords))))])
chords_index['<bos>'] = len(chords_index)
chords_index['<eos>'] = len(chords_index)

index_chords = dict(
    [(v, k) for k, v in chords_index.items()])

# %%
### Numerical variables ###
n_chords = len(chords_index)
n_notes = len(notes_index)
max_melody_seq_len = max([len(mel) for mel in melodies_by_notes])
max_chords_seq_len = max([len(section) for section in data])
ch_context_window = 5


print("Total number of distinct chord labels:", n_chords)
print("Total number of distinct melody notes:", n_notes)
print("Maximum length of melody sequences:", max_melody_seq_len)
print("Maximum length of chord sequences:", max_chords_seq_len)
print("Number of chords taken into account for next prediction:", ch_context_window)
# Out:
# Total number of distinct chord labels: 63
# Total number of distinct melody notes: 15
# Maximum length of melody sequences: 135
# Maximum length of chord sequences: 58
# Number of chords taken into account for next prediction: 5

# %%
### Build tensors ###


# Build data lists
input_melody_eos = []
input_chords_eos = []
target_chords_eos = []

for section in data:
    chord_sequence = [ch for ch, mel in section]
    padded_sequence = ['<bos>']*ch_context_window + chord_sequence + ['<eos>']
    for i in range(len(chord_sequence)+1):
        input_chords_eos.append(padded_sequence[i:i+ch_context_window])
        target_chords_eos.append(padded_sequence[i+ch_context_window])

    chord_mel = [mel for ch, mel in section]
    melody_sequence = []
    for mel in chord_mel:
        ch_mel = []
        for b in mel:
            for n in b:
                ch_mel.append(n)
        melody_sequence.append(ch_mel)
    melody_sequence += [['<end>']]
    input_melody_eos += melody_sequence
    
    
# for i in range(len(data[0])+1):
#     print(input_melody[i], input_chords[i], target_chords[i])
# print(len(input_melody), len(input_chords), len(target_chords))
    
# Remove any 
print(len(target_chords_eos), len(input_chords_eos), len(input_melody_eos))
target_chords = [target_chords_eos[i] for i in range(len(target_chords_eos)) if not target_chords_eos[i] == '<eos>']
input_chords = [input_chords_eos[i] for i in range(len(input_chords_eos)) if not target_chords_eos[i] == '<eos>']
input_melody = [input_melody_eos[i] for i in range(len(input_melody_eos)) if not target_chords_eos[i] == '<eos>']
print(len(target_chords), len(input_chords), len(input_melody))
    
    
n_entries = len(target_chords)

X_melody = np.zeros((n_entries, max_melody_seq_len, n_notes), dtype='float32')
X_chords = np.zeros((n_entries, ch_context_window, n_chords), dtype='float32')
Y = np.zeros((n_entries, n_chords), dtype='float32')



for i, (in_mel, in_ch, tg_ch) in enumerate(zip(input_melody, input_chords, target_chords)):
    Y[i, chords_index[tg_ch]] = 1
    for j, ch in enumerate(in_ch):
        X_chords[i, j, chords_index[ch]] = 1
        
    padded_melody = in_mel + ['<pad>']*(max_melody_seq_len - len(in_mel))
    for k, note in enumerate(padded_melody):
        X_melody[i, k, notes_index[note]] = 1
            
print(int(np.sum(X_melody)), n_entries*max_melody_seq_len)
print(int(np.sum(X_chords)), n_entries*ch_context_window)
print(int(np.sum(Y)), n_entries)
# Out:
# 363228 363228 363228
# 334344 334344 334344
# 45115280 45136440
# 1671720 1671720
# 334344 334344

# %%
### Train/Validation/Test sets ###
seed = 1

strat_split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=seed)

for train_index, aux_index in strat_split.split(X_chords, Y):
    X_melody_train = X_melody[train_index]
    X_chords_train = X_chords[train_index]
    Y_train = Y[train_index]
    
    X_melody_aux = X_melody[aux_index]
    X_chords_aux = X_chords[aux_index]
    Y_aux = Y[aux_index]
    
strat_split = StratifiedShuffleSplit(n_splits=1, test_size=0.5, random_state=seed)
for valid_index, test_index in strat_split.split(X_chords_aux, Y_aux):
    X_melody_valid = X_melody_aux[valid_index]
    X_chords_valid = X_chords_aux[valid_index]
    Y_valid = Y_aux[valid_index]
    
    X_melody_test = X_melody_aux[test_index]
    X_chords_test = X_chords_aux[test_index]
    Y_test = Y_aux[test_index]

print(X_melody_train.shape, X_chords_train.shape, Y_train.shape)
print(X_melody_valid.shape, X_chords_valid.shape, Y_valid.shape)
print(X_melody_test.shape, X_chords_test.shape, Y_test.shape)

# train_size = melody_train.shape[0]
# test_size = melody_test.shape[0]
# Out:
# (267475, 135, 15) (267475, 5, 63) (267475, 63)
# (33434, 135, 15) (33434, 5, 63) (33434, 63)
# (33435, 135, 15) (33435, 5, 63) (33435, 63)

# %%
### Define neural net architectur ###
latent_dim = 128

# melody_input = Input(shape=(max_melody_seq_len, n_notes))
# melody_gru = GRU(latent_dim)(melody_input)

chords_input = Input(shape=(ch_context_window, n_chords))
chords_gru = GRU(latent_dim)(chords_input)

# concat = concatenate([melody_gru, chords_gru])

chord_dense = Dense(n_chords, activation='softmax')(chords_gru)

model = Model(chords_input, chord_dense)
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

print(model.summary())
# SVG(model_to_dot(model).create(prog='dot', format='svg'))
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 5, 63)             0
# _________________________________________________________________
# gru_1 (GRU)                  (None, 128)               73728
# _________________________________________________________________
# dense_1 (Dense)              (None, 63)                8127
# =================================================================
# Total params: 81,855
# Trainable params: 81,855
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
### Introduce Early-Stopping and Save Best Performance callbacks ###
es = EarlyStopping(monitor='val_loss', min_delta=0, patience=5, verbose=1, mode='min')
filepath = "../../models/triad_cc-5_no-melody.h5"
bp = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')

# %%
### Train model ###
batch_size = 32
epochs = 50

history = model.fit(X_chords_train, Y_train, epochs=epochs, validation_data=(X_chords_valid, Y_valid,), batch_size=batch_size, callbacks=[es, bp])
# Out:
# Train on 267475 samples, validate on 33434 samples
# Epoch 1/50
# 267360/267475 [============================>.] - ETA: 0s - loss: 2.2282 - acc: 0.4332Epoch 00000: val_acc improved from -inf to 0.46842, saving model to ../../models/triad_cc-5_no-melody.h5
# 267475/267475 [==============================] - 114s - loss: 2.2282 - acc: 0.4331 - val_loss: 2.0437 - val_acc: 0.4684
# Epoch 2/50
# 267456/267475 [============================>.] - ETA: 0s - loss: 1.9160 - acc: 0.4960Epoch 00001: val_acc improved from 0.46842 to 0.51247, saving model to ../../models/triad_cc-5_no-melody.h5
# 267475/267475 [==============================] - 114s - loss: 1.9160 - acc: 0.4960 - val_loss: 1.8594 - val_acc: 0.5125
# Epoch 3/50
# 267424/267475 [============================>.] - ETA: 0s - loss: 1.7460 - acc: 0.5346Epoch 00002: val_acc improved from 0.51247 to 0.53766, saving model to ../../models/triad_cc-5_no-melody.h5
# 267475/267475 [==============================] - 113s - loss: 1.7460 - acc: 0.5346 - val_loss: 1.7354 - val_acc: 0.5377
# Epoch 4/50
# 267392/267475 [============================>.] - ETA: 0s - loss: 1.6288 - acc: 0.5599Epoch 00003: val_acc improved from 0.53766 to 0.55796, saving model to ../../models/triad_cc-5_no-melody.h5
# 267475/267475 [==============================] - 113s - loss: 1.6288 - acc: 0.5599 - val_loss: 1.6529 - val_acc: 0.5580
# Epoch 5/50
# 267360/267475 [============================>.] - ETA: 0s - loss: 1.5469 - acc: 0.5790Epoch 00004: val_acc improved from 0.55796 to 0.57316, saving model to ../../models/triad_cc-5_no-melody.h5
# 267475/267475 [==============================] - 114s - loss: 1.5469 - acc: 0.5790 - val_loss: 1.6015 - val_acc: 0.5732
# Epoch 6/50
# 267424/267475 [============================>.] - ETA: 0s - loss: 1.4857 - acc: 0.5932Epoch 00005: val_acc improved from 0.57316 to 0.57911, saving model to ../../models/triad_cc-5_no-melody.h5
# 267475/267475 [==============================] - 114s - loss: 1.4857 - acc: 0.5932 - val_loss: 1.5690 - val_acc: 0.5791
# Epoch 7/50
# 267392/267475 [============================>.] - ETA: 0s - loss: 1.4396 - acc: 0.6024Epoch 00006: val_acc improved from 0.57911 to 0.58638, saving model to ../../models/triad_cc-5_no-melody.h5
# 267475/267475 [==============================] - 113s - loss: 1.4396 - acc: 0.6024 - val_loss: 1.5336 - val_acc: 0.5864
# Epoch 8/50
# 267328/267475 [============================>.] - ETA: 0s - loss: 1.4028 - acc: 0.6101Epoch 00007: val_acc improved from 0.58638 to 0.59640, saving model to ../../models/triad_cc-5_no-melody.h5
# 267475/267475 [==============================] - 114s - loss: 1.4028 - acc: 0.6101 - val_loss: 1.5054 - val_acc: 0.5964
# Epoch 9/50
# 267360/267475 [============================>.] - ETA: 0s - loss: 1.3747 - acc: 0.6154Epoch 00008: val_acc improved from 0.59640 to 0.59649, saving model to ../../models/triad_cc-5_no-melody.h5
# 267475/267475 [==============================] - 114s - loss: 1.3747 - acc: 0.6154 - val_loss: 1.4972 - val_acc: 0.5965
# Epoch 10/50
# 267456/267475 [============================>.] - ETA: 0s - loss: 1.3516 - acc: 0.6209Epoch 00009: val_acc improved from 0.59649 to 0.60696, saving model to ../../models/triad_cc-5_no-melody.h5
# 267475/267475 [==============================] - 114s - loss: 1.3516 - acc: 0.6209 - val_loss: 1.4786 - val_acc: 0.6070
# Epoch 11/50
# 267392/267475 [============================>.] - ETA: 0s - loss: 1.3314 - acc: 0.6237Epoch 00010: val_acc did not improve
# 267475/267475 [==============================] - 114s - loss: 1.3314 - acc: 0.6237 - val_loss: 1.4724 - val_acc: 0.6048
# Epoch 12/50
# 267456/267475 [============================>.] - ETA: 0s - loss: 1.3143 - acc: 0.6272Epoch 00011: val_acc improved from 0.60696 to 0.60741, saving model to ../../models/triad_cc-5_no-melody.h5
# 267475/267475 [==============================] - 114s - loss: 1.3143 - acc: 0.6272 - val_loss: 1.4596 - val_acc: 0.6074
# Epoch 13/50
# 267328/267475 [============================>.] - ETA: 0s - loss: 1.2994 - acc: 0.6305Epoch 00012: val_acc did not improve
# 267475/267475 [==============================] - 115s - loss: 1.2995 - acc: 0.6305 - val_loss: 1.4577 - val_acc: 0.6054
# Epoch 14/50
# 267424/267475 [============================>.] - ETA: 0s - loss: 1.2874 - acc: 0.6323Epoch 00013: val_acc improved from 0.60741 to 0.60872, saving model to ../../models/triad_cc-5_no-melody.h5
# 267475/267475 [==============================] - 114s - loss: 1.2873 - acc: 0.6324 - val_loss: 1.4439 - val_acc: 0.6087
# Epoch 15/50
# 267392/267475 [============================>.] - ETA: 0s - loss: 1.2769 - acc: 0.6345Epoch 00014: val_acc improved from 0.60872 to 0.60896, saving model to ../../models/triad_cc-5_no-melody.h5
# 267475/267475 [==============================] - 115s - loss: 1.2770 - acc: 0.6344 - val_loss: 1.4392 - val_acc: 0.6090
# Epoch 16/50
# 267424/267475 [============================>.] - ETA: 0s - loss: 1.2661 - acc: 0.6367Epoch 00015: val_acc improved from 0.60896 to 0.61330, saving model to ../../models/triad_cc-5_no-melody.h5
# 267475/267475 [==============================] - 115s - loss: 1.2662 - acc: 0.6367 - val_loss: 1.4281 - val_acc: 0.6133
# Epoch 17/50
# 267424/267475 [============================>.] - ETA: 0s - loss: 1.2572 - acc: 0.6381Epoch 00016: val_acc improved from 0.61330 to 0.61551, saving model to ../../models/triad_cc-5_no-melody.h5
# 267475/267475 [==============================] - 114s - loss: 1.2573 - acc: 0.6381 - val_loss: 1.4220 - val_acc: 0.6155
# Epoch 18/50
# 267360/267475 [============================>.] - ETA: 0s - loss: 1.2494 - acc: 0.6398Epoch 00017: val_acc improved from 0.61551 to 0.61844, saving model to ../../models/triad_cc-5_no-melody.h5
# 267475/267475 [==============================] - 115s - loss: 1.2494 - acc: 0.6398 - val_loss: 1.4220 - val_acc: 0.6184
# Epoch 19/50
# 267424/267475 [============================>.] - ETA: 0s - loss: 1.2437 - acc: 0.6409Epoch 00018: val_acc did not improve
# 267475/267475 [==============================] - 114s - loss: 1.2438 - acc: 0.6409 - val_loss: 1.4138 - val_acc: 0.6149
# Epoch 20/50
# 267360/267475 [============================>.] - ETA: 0s - loss: 1.2358 - acc: 0.6425Epoch 00019: val_acc did not improve
# 267475/267475 [==============================] - 114s - loss: 1.2358 - acc: 0.6425 - val_loss: 1.4184 - val_acc: 0.6153
# Epoch 21/50
# 267424/267475 [============================>.] - ETA: 0s - loss: 1.2298 - acc: 0.6445Epoch 00020: val_acc improved from 0.61844 to 0.61856, saving model to ../../models/triad_cc-5_no-melody.h5
# 267475/267475 [==============================] - 115s - loss: 1.2297 - acc: 0.6445 - val_loss: 1.4119 - val_acc: 0.6186
# Epoch 22/50
# 267424/267475 [============================>.] - ETA: 0s - loss: 1.2245 - acc: 0.6446Epoch 00021: val_acc improved from 0.61856 to 0.61877, saving model to ../../models/triad_cc-5_no-melody.h5
# 267475/267475 [==============================] - 115s - loss: 1.2245 - acc: 0.6446 - val_loss: 1.3979 - val_acc: 0.6188
# Epoch 23/50
# 267424/267475 [============================>.] - ETA: 0s - loss: 1.2194 - acc: 0.6447Epoch 00022: val_acc improved from 0.61877 to 0.62054, saving model to ../../models/triad_cc-5_no-melody.h5
# 267475/267475 [==============================] - 115s - loss: 1.2194 - acc: 0.6447 - val_loss: 1.4037 - val_acc: 0.6205
# Epoch 24/50
# 267360/267475 [============================>.] - ETA: 0s - loss: 1.2152 - acc: 0.6456Epoch 00023: val_acc improved from 0.62054 to 0.62185, saving model to ../../models/triad_cc-5_no-melody.h5
# 267475/267475 [==============================] - 114s - loss: 1.2153 - acc: 0.6456 - val_loss: 1.3979 - val_acc: 0.6219
# Epoch 25/50
# 267392/267475 [============================>.] - ETA: 0s - loss: 1.2093 - acc: 0.6464Epoch 00024: val_acc did not improve
# 267475/267475 [==============================] - 115s - loss: 1.2093 - acc: 0.6463 - val_loss: 1.3907 - val_acc: 0.6198
# Epoch 26/50
# 267456/267475 [============================>.] - ETA: 0s - loss: 1.2056 - acc: 0.6475Epoch 00025: val_acc improved from 0.62185 to 0.62251, saving model to ../../models/triad_cc-5_no-melody.h5
# 267475/267475 [==============================] - 115s - loss: 1.2056 - acc: 0.6475 - val_loss: 1.3931 - val_acc: 0.6225
# Epoch 27/50
# 267456/267475 [============================>.] - ETA: 0s - loss: 1.2018 - acc: 0.6482Epoch 00026: val_acc improved from 0.62251 to 0.62356, saving model to ../../models/triad_cc-5_no-melody.h5
# 267475/267475 [==============================] - 114s - loss: 1.2018 - acc: 0.6482 - val_loss: 1.3911 - val_acc: 0.6236
# Epoch 28/50
# 267360/267475 [============================>.] - ETA: 0s - loss: 1.1976 - acc: 0.6490Epoch 00027: val_acc improved from 0.62356 to 0.62439, saving model to ../../models/triad_cc-5_no-melody.h5
# 267475/267475 [==============================] - 114s - loss: 1.1977 - acc: 0.6490 - val_loss: 1.3839 - val_acc: 0.6244
# Epoch 29/50
# 267424/267475 [============================>.] - ETA: 0s - loss: 1.1945 - acc: 0.6491Epoch 00028: val_acc improved from 0.62439 to 0.62448, saving model to ../../models/triad_cc-5_no-melody.h5
# 267475/267475 [==============================] - 114s - loss: 1.1945 - acc: 0.6491 - val_loss: 1.3854 - val_acc: 0.6245
# Epoch 30/50
# 267424/267475 [============================>.] - ETA: 0s - loss: 1.1910 - acc: 0.6502Epoch 00029: val_acc improved from 0.62448 to 0.62622, saving model to ../../models/triad_cc-5_no-melody.h5
# 267475/267475 [==============================] - 115s - loss: 1.1910 - acc: 0.6502 - val_loss: 1.3885 - val_acc: 0.6262
# Epoch 31/50
# 267424/267475 [============================>.] - ETA: 0s - loss: 1.1874 - acc: 0.6505Epoch 00030: val_acc improved from 0.62622 to 0.62703, saving model to ../../models/triad_cc-5_no-melody.h5
# 267475/267475 [==============================] - 115s - loss: 1.1874 - acc: 0.6505 - val_loss: 1.3817 - val_acc: 0.6270
# Epoch 32/50
# 267424/267475 [============================>.] - ETA: 0s - loss: 1.1853 - acc: 0.6508Epoch 00031: val_acc did not improve
# 267475/267475 [==============================] - 115s - loss: 1.1853 - acc: 0.6508 - val_loss: 1.3840 - val_acc: 0.6234
# Epoch 33/50
# 267456/267475 [============================>.] - ETA: 0s - loss: 1.1827 - acc: 0.6513Epoch 00032: val_acc did not improve
# 267475/267475 [==============================] - 114s - loss: 1.1827 - acc: 0.6513 - val_loss: 1.3804 - val_acc: 0.6243
# Epoch 34/50
# 267392/267475 [============================>.] - ETA: 0s - loss: 1.1795 - acc: 0.6526Epoch 00033: val_acc did not improve
# 267475/267475 [==============================] - 114s - loss: 1.1796 - acc: 0.6525 - val_loss: 1.3876 - val_acc: 0.6239
# Epoch 35/50
# 267456/267475 [============================>.] - ETA: 0s - loss: 1.1779 - acc: 0.6519Epoch 00034: val_acc did not improve
# 267475/267475 [==============================] - 115s - loss: 1.1779 - acc: 0.6519 - val_loss: 1.3801 - val_acc: 0.6270
# Epoch 36/50
# 267456/267475 [============================>.] - ETA: 0s - loss: 1.1759 - acc: 0.6522Epoch 00035: val_acc did not improve
# 267475/267475 [==============================] - 115s - loss: 1.1759 - acc: 0.6522 - val_loss: 1.3796 - val_acc: 0.6204
# Epoch 37/50
# 267360/267475 [============================>.] - ETA: 0s - loss: 1.1725 - acc: 0.6531Epoch 00036: val_acc did not improve
# 267475/267475 [==============================] - 115s - loss: 1.1726 - acc: 0.6532 - val_loss: 1.3798 - val_acc: 0.6218
# Epoch 38/50
# 267456/267475 [============================>.] - ETA: 0s - loss: 1.1716 - acc: 0.6531Epoch 00037: val_acc did not improve
# 267475/267475 [==============================] - 114s - loss: 1.1716 - acc: 0.6531 - val_loss: 1.3773 - val_acc: 0.6262
# Epoch 39/50
# 267360/267475 [============================>.] - ETA: 0s - loss: 1.1687 - acc: 0.6539Epoch 00038: val_acc improved from 0.62703 to 0.62945, saving model to ../../models/triad_cc-5_no-melody.h5
# 267475/267475 [==============================] - 115s - loss: 1.1687 - acc: 0.6539 - val_loss: 1.3719 - val_acc: 0.6294
# Epoch 40/50
# 267424/267475 [============================>.] - ETA: 0s - loss: 1.1680 - acc: 0.6536Epoch 00039: val_acc did not improve
# 267475/267475 [==============================] - 114s - loss: 1.1679 - acc: 0.6537 - val_loss: 1.3784 - val_acc: 0.6241
# Epoch 41/50
# 267360/267475 [============================>.] - ETA: 0s - loss: 1.1648 - acc: 0.6540Epoch 00040: val_acc did not improve
# 267475/267475 [==============================] - 115s - loss: 1.1647 - acc: 0.6540 - val_loss: 1.3817 - val_acc: 0.6234
# Epoch 42/50
# 267392/267475 [============================>.] - ETA: 0s - loss: 1.1632 - acc: 0.6537Epoch 00041: val_acc improved from 0.62945 to 0.63038, saving model to ../../models/triad_cc-5_no-melody.h5
# 267475/267475 [==============================] - 115s - loss: 1.1632 - acc: 0.6537 - val_loss: 1.3676 - val_acc: 0.6304
# Epoch 43/50
# 267360/267475 [============================>.] - ETA: 0s - loss: 1.1621 - acc: 0.6544Epoch 00042: val_acc did not improve
# 267475/267475 [==============================] - 115s - loss: 1.1622 - acc: 0.6544 - val_loss: 1.3692 - val_acc: 0.6278
# Epoch 44/50
# 267456/267475 [============================>.] - ETA: 0s - loss: 1.1609 - acc: 0.6544Epoch 00043: val_acc did not improve
# 267475/267475 [==============================] - 115s - loss: 1.1610 - acc: 0.6544 - val_loss: 1.3717 - val_acc: 0.6283
# Epoch 45/50
# 267392/267475 [============================>.] - ETA: 0s - loss: 1.1590 - acc: 0.6557Epoch 00044: val_acc did not improve
# 267475/267475 [==============================] - 115s - loss: 1.1590 - acc: 0.6557 - val_loss: 1.3653 - val_acc: 0.6295
# Epoch 46/50
# 267360/267475 [============================>.] - ETA: 0s - loss: 1.1579 - acc: 0.6557Epoch 00045: val_acc improved from 0.63038 to 0.63106, saving model to ../../models/triad_cc-5_no-melody.h5
# 267475/267475 [==============================] - 115s - loss: 1.1579 - acc: 0.6557 - val_loss: 1.3641 - val_acc: 0.6311
# Epoch 47/50
# 267360/267475 [============================>.] - ETA: 0s - loss: 1.1567 - acc: 0.6551Epoch 00046: val_acc did not improve
# 267475/267475 [==============================] - 115s - loss: 1.1566 - acc: 0.6552 - val_loss: 1.3676 - val_acc: 0.6301
# Epoch 48/50
# 267456/267475 [============================>.] - ETA: 0s - loss: 1.1540 - acc: 0.6565Epoch 00047: val_acc did not improve
# 267475/267475 [==============================] - 115s - loss: 1.1540 - acc: 0.6565 - val_loss: 1.3640 - val_acc: 0.6277
# Epoch 49/50
# 267424/267475 [============================>.] - ETA: 0s - loss: 1.1531 - acc: 0.6559Epoch 00048: val_acc did not improve
# 267475/267475 [==============================] - 114s - loss: 1.1531 - acc: 0.6559 - val_loss: 1.3659 - val_acc: 0.6279
# Epoch 50/50
# 267328/267475 [============================>.] - ETA: 0s - loss: 1.1518 - acc: 0.6561Epoch 00049: val_acc did not improve
# 267475/267475 [==============================] - 115s - loss: 1.1518 - acc: 0.6561 - val_loss: 1.3638 - val_acc: 0.6291

# %%
### Visualize model learning ###
plt.clf()

plt.figure(figsize=(15,5))
plt.subplot(1, 2, 1)
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
# plt.show()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.tight_layout()
plt.suptitle("Training history of root model", fontsize=16)
plt.subplots_adjust(top=0.85)
plt.show()

# %%
### Load best performance model ###
model = load_model("../../models/triad_cc-5_no-melody.h5")

# %%
### Evaluate predictions ###

# Predict chords from each test sample melody
chord_pred = model.predict(X_chords_test)

    
# Compute accuracy and kappa score 
print("Categorical accuracy of combined chord prediction: {0:.4f}".format(harmoutil.compute_accuracy_score(Y_test, chord_pred)))
# print("Precision of combined chord prediction: {0:.4f}".format(harmoutil.compute_precision_score(Y_test, chord_pred)))
# print("Recall of combined chord prediction: {0:.4f}".format(harmoutil.compute_recall_score(Y_test, chord_pred)))
print("Kappa score of combined chord prediction: {0:.4f}".format(harmoutil.compute_kappa_score(Y_test, chord_pred)))
# Out:
# Categorical accuracy of combined chord prediction: 0.6342
# Kappa score of combined chord prediction: 0.6156

# %%
### Visualize prediction ###
chord_test_labels = [index_chords[np.argmax(row)] for row in Y_test]
chord_pred_labels = [index_chords[np.argmax(row)] for row in chord_pred]

chord_cm = confusion_matrix(chord_test_labels, chord_pred_labels)

labels = sorted(list(set(chord_test_labels)))
# print(labels)
plt.figure(figsize=(15,15))              
ax = plt.axes()                 
im = ax.matshow(chord_cm)      
plt.colorbar(im, ax=ax)               
plt.xticks(np.arange(len(labels)), labels, rotation='vertical')
plt.yticks(np.arange(len(labels)), labels)
plt.show()
